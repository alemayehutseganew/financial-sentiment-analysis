# %% [markdown]
# # 01 - Exploratory Data Analysis
# This notebook demonstrates how to run basic EDA on the news dataset.

# %%
# Install packages if needed
# !pip install -r ../requirements.txt

import os
import sys
from pathlib import Path

# Ensure repo root is on sys.path so src can be imported
repo_root = Path.cwd().resolve().parent
if repo_root.name == 'notebooks':
    repo_root = repo_root.parent
sys.path.append(str(repo_root))  # noqa: SIM105

import pandas as pd
import importlib
from src import eda
importlib.reload(eda)
headline_length_stats = eda.headline_length_stats
publisher_counts = eda.publisher_counts
from src.data_loader import load_news_csv

news_path = 'C:/Users/alexo/Desktop/File/10Academy/week1/Data/newsData/raw_analyst_ratings.csv'  # replace with your path
try:
    news = load_news_csv(news_path)
    print(headline_length_stats(news))
    print(publisher_counts(news).head(10))
except Exception as e:
    print('Could not find news CSV at', news_path)
# Out:
# {'count': 1407328, 'min_words': 1, 'max_words': 77, 'mean_words': 11.416705984674504, 'median_words': 10.0}
# publisher
# Paul Quintaro        228373
# Lisa Levin           186979
# Benzinga Newsdesk    150484
# Charles Gross         96732
# Monica Gerson         82380
# Eddie Staley          57254
# Hal Lindon            49047
# ETF Professor         28489
# Juan Lopez            28438
# Benzinga Staff        28114
# Name: count, dtype: int64
